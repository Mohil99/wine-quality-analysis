# %% [markdown]
# # Problem Datasets:
#
# ## Dataset Overview: The datasets contain information about the chemical properties of red and white wines, along with a quality rating based on sensory testing. Your goal is to use data visualization techniques (Matplotlib & Seaborn) to explore and present insights about the relationship between chemical features and the quality of wine.
#
# ## You are tasked with generating several visualizations to identify trends, correlations, and key insights in the data. Use appropriate visualizations like histograms, boxplots, heatmaps, and scatter plots to better understand the data.

# %% [markdown]
# # Summary:
#
# ## The tasks above focus on using Matplotlib and Seaborn to explore, analyze, and visualize the relationships between various chemical properties of wine and the quality rating. These visualizations will help you uncover trends, correlations, and insights into what influences wine quality. After completing the tasks, you should be able to identify key features and their impact on wine quality, and present your findings with clear visual evidence.

# %%
#Importing all the libraries:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
#importing the file

# %%
df = pd.read_csv(r"C:\Users\adity\Downloads\wine+quality\winequality-red.csv",sep= ';',quotechar='"')
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
df.shape
# Out:
# (1599, 12)

# %%
df.describe().T
# Out:
#                        count       mean        std      min      25%  \
# fixed acidity         1599.0   8.319637   1.741096  4.60000   7.1000
# volatile acidity      1599.0   0.527821   0.179060  0.12000   0.3900
# citric acid           1599.0   0.270976   0.194801  0.00000   0.0900
# residual sugar        1599.0   2.538806   1.409928  0.90000   1.9000
# chlorides             1599.0   0.087467   0.047065  0.01200   0.0700
# free sulfur dioxide   1599.0  15.874922  10.460157  1.00000   7.0000
# total sulfur dioxide  1599.0  46.467792  32.895324  6.00000  22.0000
# density               1599.0   0.996747   0.001887  0.99007   0.9956
# pH                    1599.0   3.311113   0.154386  2.74000   3.2100
# sulphates             1599.0   0.658149   0.169507  0.33000   0.5500
# alcohol               1599.0  10.422983   1.065668  8.40000   9.5000
# quality               1599.0   5.636023   0.807569  3.00000   5.0000
#
#                            50%        75%        max
# ...

# %% [markdown]
# # Task 1: Basic Distribution of Numerical Variables
# ### Goal: Visualize the distribution of key numerical features.
#
# # Task:
# ### Use histograms to display the distribution of the following numerical features: fixed_acidity ,volatile_acidity , residual_sugar , chlorides , free_sulfur_dioxide ,total_sulfur_dioxide , density , ph , sulphates , and alcohol .
#
# ### What patterns or trends can you observe from the distributions? Are there any features with skewed distributions or outliers?

# %%
numerical_data = ["fixed_acidity" ,
        "volatile_acidity" , 
        "residual_sugar" , 
        "chlorides" , 
        "free_sulfur_dioxide" ,
        "total_sulfur_dioxide" , 
        "density" ,
        "ph" ,
        "sulphates" ,
        "alcohol"
       ]

# %%
#Plotting histogram for all the numerical features

# %%
df.hist( bins = 20, edgecolor ="black", figsize=(15,12))

plt.xticks(rotation=90)

plt.show()

# %% [markdown]
# # What patterns or trends can you observe from the distributions? Are there any features with skewed distributions or outliers?

# %% [markdown]
# ### From the above Histogram visualization, we can see that the Frequency count of all the key numerical features listed as follows:
# ["fixed_acidity" ,"volatile_acidity" , "residual_sugar" , "chlorides" , "free_sulfur_dioxide" ,"total_sulfur_dioxide" , "density" ,"ph" ,"sulphates" ,"alcohol"]
# ***have the same frequency count***

# %% [markdown]
# ### To check the outliers we need to use Box Plot

# %%
plt.boxplot(df)
plt.xlabel("Features")
plt.title("Box-plot")
plt.show()

# %% [markdown]
# ### As you can see from the above Box Plot visualization all the numerical features
# ["fixed_acidity" ,"volatile_acidity" , "residual_sugar" , "chlorides" , "free_sulfur_dioxide" ,"total_sulfur_dioxide" , "density" ,"ph" ,"sulphates" ,"alcohol"]
#
# ***Have outliers***

# %% [markdown]
# # Task 2: Correlation Heatmap
# ### Goal: Visualize relationships between numerical features.
# # Task:
# ### Create a correlation heatmap to visualize the correlations between the numerical variables.
# ### Highlight and discuss any strong positive or negative correlations, especially those that could influence wine quality. Which variables seem to be most closely related?

# %%
correlation = df.corr()

# %%
plt.figure(figsize=(15, 12))
sns.heatmap(correlation, annot=True, cmap='coolwarm', center=0)
plt.title('Correlation Heatmap of the numerical features')
plt.show()

# %% [markdown]
# ## Highlight and discuss any strong positive or negative correlations, especially those that could influence wine quality. Which variables seem to be most closely related?

# %% [markdown]
# # Strong positive correlation:
#
# **Alcohol has the strongest positive correlation in terms of wine quality**
#
# **It's because better the amount of alcohol content, better the quality of wine would be**

# %% [markdown]
# # Strong negative correlation:
#
# **volatile acidity is the one which could affect the quality of the win negatively the most out of all the other features presented**

# %% [markdown]
# ***Most closely related variable in the entire heatmap are:***
#
# **citric acid**
#
# **fixed acidity**
#
# **density**
#
# **total sulfur dioxide**
#
# **free sulfur dioxide**

# %% [markdown]
# # Task 3: Wine Quality vs Alcohol Content
# ### Goal: Explore the relationship between wine quality and alcohol content.
#
# # Task:
# ### Create a boxplot that shows the distribution of alcohol across different quality ratings.
# ### What trends or patterns do you observe? Does higher alcohol content generally correlate with higher wine quality?

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(12, 8))
sns.boxplot(x='quality', y='alcohol', data=df)
plt.title('wine quality vs alcohol content')
plt.xlabel('wine quality')
plt.ylabel('alcohol content')
plt.show()

# %% [markdown]
# # What trends or patterns do you observe? Does higher alcohol content generally correlate with higher wine quality?

# %% [markdown]
# ### alcohol content has weak correlation with  wine quality
#
# **From the heatmap, we can observe the correlation between it to be of (0.48) which falls in weak correlation.**
#
# **Although it can still be consider a strong correlation between 'alcohol' and 'quality' as its the only correlation which is relatively high when compared with other features in it**

# %% [markdown]
# # Task 4: Quality Distribution
# ## Goal: Understand the distribution of wine quality scores.
# # Task:
# ### Use a countplot to visualize how wine quality is distributed (i.e., how often each quality score appears in the dataset).
# ### Which quality rating appears most frequently? Discuss the percentage of wines that have this common quality.

# %%
wine_quality = df["quality"]

# %%
sns.countplot(x="quality",data = df,palette = "viridis")
plt.title("wine quality frequency/count")
plt.xlabel("wine quality")
plt.ylabel("frequency")
plt.show()

# %% [markdown]
# # Which quality rating appears most frequently? Discuss the percentage of wines that have this common quality.

# %% [markdown]
# ### "wine quality-5" appears most frequently while "wine quaity-6" follows it closely behind.

# %% [markdown]
# # Task 5: Visualizing Distribution of Key Variables with Boxplots and Histograms
# ## Goal: Explore relationships between wine quality and several key chemical features.
# # Task:
# ## Visualize the distribution of key variables (alcohol, sulphates, citric acid, and fixed_acidity) with boxplots and histograms.
# ## What do you observe about how wine quality is related to these features? Are there any patterns that stand out? note: Create a subplot showing boxplots and histograms for each of the selected features (alcohol, sulphates, citric_acid, and fixed_acidity) with a title describing the feature being visualized.

# %%
df.describe().T
# Out:
#                        count       mean        std      min      25%  \
# fixed acidity         1599.0   8.319637   1.741096  4.60000   7.1000
# volatile acidity      1599.0   0.527821   0.179060  0.12000   0.3900
# citric acid           1599.0   0.270976   0.194801  0.00000   0.0900
# residual sugar        1599.0   2.538806   1.409928  0.90000   1.9000
# chlorides             1599.0   0.087467   0.047065  0.01200   0.0700
# free sulfur dioxide   1599.0  15.874922  10.460157  1.00000   7.0000
# total sulfur dioxide  1599.0  46.467792  32.895324  6.00000  22.0000
# density               1599.0   0.996747   0.001887  0.99007   0.9956
# pH                    1599.0   3.311113   0.154386  2.74000   3.2100
# sulphates             1599.0   0.658149   0.169507  0.33000   0.5500
# alcohol               1599.0  10.422983   1.065668  8.40000   9.5000
# quality               1599.0   5.636023   0.807569  3.00000   5.0000
#
#                            50%        75%        max
# ...

# %%
chemical_features = ["alcohol",
                     "sulphates",
                     "citric acid",
                     "fixed acidity"
                    ]

# %%
plt.figure(figsize=(15,12))

for i, feature in enumerate(chemical_features, 1):
    
    
#for boxplot
    plt.subplot(2,4,i)
    sns.boxplot(x=df[feature])
    plt.title(f"Boxplot of {feature}")

#for histogram
    plt.subplot(2,4, i+4)
    sns.histplot(df[feature], kde=True, bins = 15 , color ="green")
    plt.title(f"Histogram of {feature}")

plt.show()

# %% [markdown]
# # Task 6: Scatter Plot for Fixed Acidity vs Alcohol Content
# ## Goal: Investigate the relationship between acidity and alcohol content.
# # Task:
# ## Create scatter plots to analyze the relationship between fixed_acidity and alcohol , as well as volatile_acidity and alcohol .
# ## Do you observe any trends or patterns? How do these variables appear to correlate with each other?

# %%
facidity = df["fixed acidity"]
vacidity = df["volatile acidity"]
alcohol_content = df["alcohol"]

# %%
plt.scatter(facidity,alcohol_content)
plt.scatter(vacidity,alcohol_content)

plt.title("alcohol vs fixed acidity and volatile acidity")
plt.xlabel("alcohol content")
plt.legend(["Fixed Aciity","Volatile Acidity"])
plt.show()

# %% [markdown]
# # Do you observe any trends or patterns? How do these variables appear to correlate with each other?

# %% [markdown]
# *From the above scatter plot, we can visualize that the features ["alcohol", "fixed acidity", "volatile acidity"] have weak correlation between them*
#
# *Since whenever alcohol content increases not necessarily fixed acidity and volatile acidity also increases*

# %% [markdown]
# # Task 7: Impact of Sulfur Dioxide on Wine Quality
# ## Goal: Explore the impact of sulfur dioxide levels on wine quality.
# # Task:
# ## Create scatter plots to show the relationship between free_sulfur_dioxide and quality , and between total_sulfur_dioxide and quality .between total_sulfur_dioxide and quality .
# ## How does the presence of sulfur dioxide seem to influence the quality rating of wine?

# %%
fsd = df["free sulfur dioxide"]
tsd = df["total sulfur dioxide"]
wine_quality = df["quality"]

# %%
plt.scatter(fsd,wine_quality)
plt.scatter(tsd,wine_quality)

plt.title("wine quality vs free sulfur dioxide and total sulfur dioxide")
plt.xlabel("wine quality")
plt.legend(["Free Sulfur Dioxide","Total Sulfur Dioxide"])
plt.show()

# %%
plt.scatter(wine_quality, fsd)
plt.title('wine quality vs free sulfur dioxide')
plt.xlabel('fsd')
plt.ylabel('wine quality')
plt.show()

# %%
plt.scatter(wine_quality, fsd)
plt.title('wine quality vs total sulfur dioxide')
plt.xlabel('tsd')
plt.ylabel('wine quality')
plt.show()

# %% [markdown]
# ## How does the presence of sulfur dioxide seem to influence the quality rating of wine?

# %% [markdown]
# *The correlation between wine quality and sulfur dioxide (whether its free sulfur dioxide or total sulfur dioxide) is really weak*

# %% [markdown]
# # Task 8: Boxplot for Quality vs Various Features
# ## Goal: Explore the impact of several features on wine quality.
# # Task:
# ## For each of the following features ( fixed_acidity , residual_sugar , sulphates , citric_acid , density ), create a boxplot showing how the feature values vary across different wine quality ratings.
# ## Which features show the most variation across quality ratings? Are there clear patterns that indicate which features influence wine quality?

# %%
plt.boxplot(df["fixed acidity"])
plt.xlabel("Fixed acidity")
plt.title("Box-plot")
plt.show()

# %%
plt.boxplot(df["residual sugar"])
plt.xlabel("residual sugar")
plt.title("Box-plot")
plt.show()

# %%
plt.boxplot(df["sulphates"])
plt.xlabel("sulphates")
plt.title("Box-plot")
plt.show()

# %%
plt.boxplot(df["citric acid"])
plt.xlabel("citric acid")
plt.title("Box-plot")
plt.show()

# %%
plt.boxplot(df["density"])
plt.xlabel("density")
plt.title("Box-plot")
plt.show()

# %%
plt.figure(figsize=(12,8))
plt.subplot(3,2,1)
sns.boxplot(x="quality",y="fixed acidity",data=df,palette="viridis")
plt.title("quality vs fixed acidity")
plt.show()

# %%
plt.figure(figsize=(12,8))
plt.subplot(3,2,2)
sns.boxplot(x="quality",y="residual sugar",data=df,palette="viridis")
plt.title("quality vs residual sugar")
plt.show()

# %%
plt.figure(figsize=(12,8))
plt.subplot(3,2,3)
sns.boxplot(x="quality",y="sulphates",data=df,palette="viridis")
plt.title("quality vs sulphates")
plt.show()
